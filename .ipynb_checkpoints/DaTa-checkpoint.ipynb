# %% [markdown]
# ## NAME: Deborah Hammond
#
# ## ID: 10958833
#
# ## DEPARTMENT: Material Science and Engineering

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df= pd.read_csv("C:/Users/I.T CREATIVE PLUS/Downloads/Telegram Desktop/data.csv")
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
df.isnull()
# Out:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 1596  False          False             False        False           False
# 1597  False          False             False        False           False
# 1598  False          False             False        False           False
# 1599  False          False             False        False           False
# 1600  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
df.dropna(inplace = True)
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
## I used the drop method to clean the null values because it saves time

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %%
new=df.rename(columns={'fixed acidity':'fixed_acidity', 'citric acid':'citric_acid', 'volatile acidity':'volatile_acidity', 'residual sugar':'residual_sugar', 'free sulfur dioxide':'free_sulfur_dioxide', 'total sulfur dioxide':'total_sulfur_dioxide'})
new
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed_acidity         1591 non-null   float64
#  2   volatile_acidity      1591 non-null   float64
#  3   citric_acid           1591 non-null   float64
#  4   residual_sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free_sulfur_dioxide   1591 non-null   float64
#  7   total_sulfur_dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %%
new.duplicated().sum()
# Out:
# 0

# %%
new.isnull().sum()
# Out:
# ID                      0
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
mean_fd= new.fixed_acidity.mean()
mean_vd= new.volatile_acidity.mean()
mean_cd= new.citric_acid.mean()
mean_rs= new.residual_sugar.mean()
mean_cl= new.chlorides.mean()
mean_fsd= new.free_sulfur_dioxide.mean()
mean_tsd= new.total_sulfur_dioxide.mean()
mean_dy= new.density.mean()
mean_pH= new.pH.mean()
mean_sl= new.sulphates.mean()
mean_al= new.alcohol.mean()
mean_ql= new.quality.mean()

# %%
print(f'fixed_acidity:{mean_fd}')
print(f'volatile_acidity:{mean_vd}')
print(f'citric_acid:{mean_cd}')
print(f'residual_sugar:{mean_rs}')
print(f'chlorides:{mean_cl}')
print(f'free_sulfur_dioxide:{mean_fsd}')
print(f'total_sulfur_dioxide:{mean_tsd}')
print(f'density:{mean_dy}')
print(f'pH:{mean_pH}')
print(f'sulphates:{mean_sl}')
print(f'alcohol:{mean_al}')
print(f'quality:{mean_ql}')
# Out:
# fixed_acidity:8.32061596480201
# volatile_acidity:0.5276807039597737
# citric_acid:0.27147705845380266
# residual_sugar:2.5407605279698307
# chlorides:0.08749968573224387
# free_sulfur_dioxide:15.861722187303583
# total_sulfur_dioxide:46.49842866121936
# density:0.9967465304839724
# pH:3.3113576367064743
# sulphates:0.6586109365179132
# alcohol:10.42605279698303
# quality:5.637963544940289

# %%
median_fd= new.fixed_acidity.median()
median_vd= new.volatile_acidity.median()
median_cd= new.citric_acid.median()
median_rs= new.residual_sugar.median()
median_cl= new.chlorides.median()
median_fsd= new.free_sulfur_dioxide.median()
median_tsd= new.total_sulfur_dioxide.median()
median_dy= new.density.median()
median_pH= new.pH.median()
median_sl= new.sulphates.median()
median_al= new.alcohol.median()
median_ql= new.quality.median()

# %%
print(f'fixed_acidity:{median_fd}')
print(f'volatile_acidity:{median_vd}')
print(f'citric_acid:{median_cd}')
print(f'residual_sugar:{median_rs}')
print(f'chlorides:{median_cl}')
print(f'free_sulfur_dioxide:{median_fsd}')
print(f'total_sulfur_dioxide:{median_tsd}')
print(f'density:{median_dy}')
print(f'pH:{median_pH}')
print(f'sulphates:{median_sl}')
print(f'alcohol:{median_al}')
print(f'quality:{median_ql}')
# Out:
# fixed_acidity:7.9
# volatile_acidity:0.52
# citric_acid:0.26
# residual_sugar:2.2
# chlorides:0.079
# free_sulfur_dioxide:14.0
# total_sulfur_dioxide:38.0
# density:0.99675
# pH:3.31
# sulphates:0.62
# alcohol:10.2
# quality:6.0

# %%
mode_fd= new.fixed_acidity.mode()
mode_vd= new.volatile_acidity.mode()
mode_cd= new.citric_acid.mode()
mode_rs= new.residual_sugar.mode()
mode_cl= new.chlorides.mode()
mode_fsd= new.free_sulfur_dioxide.mode()
mode_tsd= new.total_sulfur_dioxide.mode()
mode_dy= new.density.mode()
mode_pH= new.pH.mode()
mode_sl= new.sulphates.mode()
mode_al= new.alcohol.mode()
mode_ql= new.quality.mode()

# %%
print(f'fixed_acidity:{mode_fd}')
print(f'volatile_acidity:{mode_vd}')
print(f'citric_acid:{mode_cd}')
print(f'residual_sugar:{mode_rs}')
print(f'chlorides:{mode_cl}')
print(f'free_sulfur_dioxide:{mode_fsd}')
print(f'total_sulfur_dioxide:{mode_tsd}')
print(f'density:{mode_dy}')
print(f'pH:{mode_pH}')
print(f'sulphates:{mode_sl}')
print(f'alcohol:{mode_al}')
print(f'quality:{mode_ql}')
# Out:
# fixed_acidity:0    7.2
# Name: fixed_acidity, dtype: float64
# volatile_acidity:0    0.6
# Name: volatile_acidity, dtype: float64
# citric_acid:0    0.0
# Name: citric_acid, dtype: float64
# residual_sugar:0    2.0
# Name: residual_sugar, dtype: float64
# chlorides:0    0.08
# Name: chlorides, dtype: float64
# free_sulfur_dioxide:0    6.0
# Name: free_sulfur_dioxide, dtype: float64
# total_sulfur_dioxide:0    28.0
# Name: total_sulfur_dioxide, dtype: float64
# density:0    0.9972
# Name: density, dtype: float64
# pH:0    3.3
# Name: pH, dtype: float64
# sulphates:0    0.6
# Name: sulphates, dtype: float64
# alcohol:0    9.5
# Name: alcohol, dtype: float64
# quality:0    5.0
# Name: quality, dtype: float64

# %%
std_fd= new.fixed_acidity.std()
std_vd= new.volatile_acidity.std()
std_cd= new.citric_acid.std()
std_rs= new.residual_sugar.std()
std_cl= new.chlorides.std()
std_fsd= new.free_sulfur_dioxide.std()
std_tsd= new.total_sulfur_dioxide.std()
std_dy= new.density.std()
std_pH= new.pH.std()
std_sl= new.sulphates.std()
std_al= new.alcohol.std()
std_ql= new.quality.std()

# %%
print(f'fixed_acidity:{std_fd}')
print(f'volatile_acidity:{std_vd}')
print(f'citric_acid:{std_cd}')
print(f'residual_sugar:{std_rs}')
print(f'chlorides:{std_cl}')
print(f'free_sulfur_dioxide:{std_fsd}')
print(f'total_sulfur_dioxide:{std_tsd}')
print(f'density:{std_dy}')
print(f'pH:{std_pH}')
print(f'sulphates:{std_sl}')
print(f'alcohol:{std_al}')
print(f'quality:{std_ql}')
# Out:
# fixed_acidity:1.7401336962216718
# volatile_acidity:0.1790451469674224
# citric_acid:0.19480651409147987
# residual_sugar:1.4130755475184043
# chlorides:0.0471746637430755
# free_sulfur_dioxide:10.429384554681942
# total_sulfur_dioxide:32.998658692691784
# density:0.0018891416386783645
# pH:0.15454755939895115
# sulphates:0.16978645516738008
# alcohol:1.0667057613499136
# quality:0.8077716074110152

# %% [markdown]
# ## Satistical Inference for the entire columns

# %%
sns.histplot(new)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Satistical inference for individual columns

# %%
sns.histplot(new['fixed_acidity'])
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %%
sns.histplot(new['volatile_acidity'])
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Count'>

# %%
sns.histplot(new['citric_acid'])
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %%
sns.histplot(new['residual_sugar'])
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %%
sns.histplot(new['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(new['free_sulfur_dioxide'])
# Out:
# <Axes: xlabel='free_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(new['total_sulfur_dioxide'])
# Out:
# <Axes: xlabel='total_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(new['density'])
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
sns.histplot(new['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(new['sulphates'])
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %%
sns.histplot(new['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(new['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
sns.barplot(x='pH', y='alcohol',data=new)
plt.show()

# %% [markdown]
# # Hidden inferences

# %%
sns.scatterplot(x='pH', y='alcohol', data=new)
# Out:
# <Axes: xlabel='pH', ylabel='alcohol'>

# %%
sns.scatterplot(x='pH', y='fixed_acidity', data=new)
# Out:
# <Axes: xlabel='pH', ylabel='fixed_acidity'>

# %%
sns.scatterplot(x='pH', y='density', data=new)
# Out:
# <Axes: xlabel='pH', ylabel='density'>

# %%
sns.scatterplot(x='alcohol', y='residual_sugar', data=new)
# Out:
# <Axes: xlabel='alcohol', ylabel='residual_sugar'>

# %% [markdown]
# # Data correlation

# %%
corr=new.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >
